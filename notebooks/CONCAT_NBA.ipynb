# %%
import pandas as pd 
import numpy as np

# %%
df_nba = pd.read_csv('NBA_LIMPIO.csv')

# %%
df_concat = pd.read_csv('CONCAT_NBA1.csv')

# %%
df_concat
# Out:
#                Player Team  GP   MPG  PPG  FGM  FGA    FG%  3PM  3PA  ...  \
# 0          Toni Kukoc  MIL  53  20.7  5.6  2.0  4.8  0.410  0.8  2.2  ...
# 1       Howard Eisley  UTA  74  19.3  5.6  2.2  5.5  0.398  0.4  1.4  ...
# 2   Junior Harrington  NOP  29  18.9  5.6  2.2  6.1  0.360  0.2  0.7  ...
# 3       Nick Collison  SEA  82  17.0  5.6  2.3  4.3  0.537  0.0  0.0  ...
# 4        Devin Harris  DAL  76  15.4  5.7  2.1  4.8  0.429  0.6  1.7  ...
# ..                ...  ...  ..   ...  ...  ...  ...    ...  ...  ...  ...
# 95        Troy Hudson  MIN  79  21.9  8.7  3.4  8.4  0.401  1.1  3.3  ...
# 96     Gordan Giricek  UTA  81  20.5  8.8  3.5  7.8  0.448  0.5  1.3  ...
# 97    Austin Croshere  IND  73  25.0  8.9  2.6  6.8  0.378  0.6  2.4  ...
# 98       Matt Carroll  CHA  25  17.2  9.0  2.8  7.2  0.389  0.5  1.6  ...
# 99     Brian Cardinal  MEM  58  24.7  9.0  2.8  7.4  0.370  0.8  2.2  ...
#
#       FT%  ORB  DRB  RPG  APG  SPG  BPG  TOV   PF     Season
# ...

# %%
NBA = pd.concat([df_concat,df_nba],axis=1)

# %%
df_nba
# Out:
#                      Player Team  GP   MPG   PPG  FGM   FGA    FG%  3PM  3PA  \
# 0              Pepe Sanchez  DET   9   4.1   0.0  0.0   0.6  0.000  0.0  0.0
# 1             Jamal Sampson  MIL   5   1.6   0.0  0.0   0.4  0.000  0.0  0.0
# 2     Ruben Boumtje-Boumtje  POR   2   2.5   0.0  0.0   0.5  0.000  0.0  0.0
# 3                Guy Rucker  GSW   3   1.3   0.0  0.0   0.0  0.000  0.0  0.0
# 4              Chris Dudley  POR   3   3.7   0.0  0.0   0.3  0.000  0.0  0.0
# ...                     ...  ...  ..   ...   ...  ...   ...    ...  ...  ...
# 6095          Kevin Huerter  ATL  69  30.8  11.9  4.6  10.6  0.432  2.0  5.6
# 6096           Jordan Poole  GSW  51  19.4  12.0  4.0   9.3  0.432  1.9  5.4
# 6097             Joe Ingles  UTA  67  27.9  12.1  4.1   8.4  0.489  2.7  6.1
# 6098         Thaddeus Young  CHI  68  24.3  12.1  5.4   9.7  0.559  0.2  0.7
# 6099        Josh Richardson  DAL  59  30.3  12.1  4.5  10.5  0.427  1.5  4.5
#
# ...

# %%
result = pd.concat([df_nba, df_concat], join='inner', ignore_index=True)

# %%
df_nba.shape
# Out:
# (6100, 23)

# %%
result
# Out:
#                      Player Team  GP   MPG  PPG  FGM  FGA    FG%  3PM  3PA  \
# 0              Pepe Sanchez  DET   9   4.1  0.0  0.0  0.6  0.000  0.0  0.0
# 1             Jamal Sampson  MIL   5   1.6  0.0  0.0  0.4  0.000  0.0  0.0
# 2     Ruben Boumtje-Boumtje  POR   2   2.5  0.0  0.0  0.5  0.000  0.0  0.0
# 3                Guy Rucker  GSW   3   1.3  0.0  0.0  0.0  0.000  0.0  0.0
# 4              Chris Dudley  POR   3   3.7  0.0  0.0  0.3  0.000  0.0  0.0
# ...                     ...  ...  ..   ...  ...  ...  ...    ...  ...  ...
# 6195            Troy Hudson  MIN  79  21.9  8.7  3.4  8.4  0.401  1.1  3.3
# 6196         Gordan Giricek  UTA  81  20.5  8.8  3.5  7.8  0.448  0.5  1.3
# 6197        Austin Croshere  IND  73  25.0  8.9  2.6  6.8  0.378  0.6  2.4
# 6198           Matt Carroll  CHA  25  17.2  9.0  2.8  7.2  0.389  0.5  1.6
# 6199         Brian Cardinal  MEM  58  24.7  9.0  2.8  7.4  0.370  0.8  2.2
#
#       ...    FT%  ORB  DRB  RPG  APG  SPG  BPG  TOV   PF     Season
# ...

# %%
result.to_csv('NBA_LIMPIO.csv',index=False)
